# %% [markdown]
# ### Project 2 Example Notebook

# %%
## Loading necessary packages

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.datasets import make_classification

# %% [markdown]
# #### Notebook Purpose
#
# This notebook covers the basic skills needed for Project 2
#
# 1. Ingest csv data
# 2. Basic data processing
# 3. Train model
# 5. Assess model on known labels
# 6. Score test rows

# %% [markdown]
# #### Core data processing

# %%
df_train = pd.read_csv('train.csv')
df_train.head()
# Out:
#   creation_date      zip  ward  police_district  community_area  latitude  \
# 0    2012-03-02  60656.0  41.0             16.0            10.0    41.975
# 1    2016-03-31  60659.0  50.0             24.0             2.0    41.995
# 2    2018-02-27  60634.0  36.0             25.0            19.0    41.937
# 3    2011-04-06  60632.0  14.0              9.0            63.0    41.794
# 4    2018-03-28  60643.0  34.0             22.0            75.0    41.680
#
#    longitude  ssa current_activity  number_of_potholes_filled_on_block  \
# 0    -87.795  NaN    Dispatch Crew                                 5.0
# 1    -87.685  NaN    Final Outcome                                 4.0
# 2    -87.788  NaN    Final Outcome                                76.0
# 3    -87.688  NaN    Dispatch Crew                                 0.0
# 4    -87.669  NaN              NaN                                 NaN
#
#    completed_within_7_days                            request_id
# 0                        1  c6fb34de-4e79-4e83-ac3b-cbbf31d6d834
# 1                        1  a50411a7-2c2c-439c-8cd1-62cf18fc2d4a
# 2                        1  55eb1b82-ae52-4e1a-9476-169a59293cf0
# 3                        1  59a51854-7646-40d5-a30f-04306a6f9d2f
# 4                        1  06dbfc49-3118-4849-ad24-5d2fd3b1760b

# %%
df_test = pd.read_csv('test.csv')
df_test.head()
# Out:
#   creation_date      zip  ward  police_district  community_area  latitude  \
# 0    2017-02-06  60625.0  40.0             20.0             4.0    41.981
# 1    2012-04-13  60637.0   5.0              3.0            42.0    41.779
# 2    2011-08-11  60625.0  39.0             17.0            13.0    41.979
# 3    2014-04-29  60642.0   1.0             14.0            24.0    41.905
# 4    2012-08-02  60637.0   5.0              3.0            42.0    41.782
#
#    longitude   ssa current_activity  number_of_potholes_filled_on_block  \
# 0    -87.689   NaN              NaN                                 NaN
# 1    -87.585   NaN    Dispatch Crew                                86.0
# 2    -87.713   NaN    Dispatch Crew                                14.0
# 3    -87.666  33.0              NaN                                 NaN
# 4    -87.585   NaN    Final Outcome                                11.0
#
#                              request_id
# 0  b98b4a12-1e86-4634-b7e6-8a8d4c687ef6
# 1  90ad3297-203b-4636-81fa-26e279a323e6
# 2  c5e678b6-5fe5-4bc5-97ed-a9df3ba7f197
# 3  734f19b6-1a03-40f7-9aa0-2a575ff65fcc
# 4  f9cf7e4f-5745-4685-8378-03ee40040cc8

# %%
#### concatenating the two datasets together so that they get the same data processing before modeling 

df_full = pd.concat([df_train, df_test], ignore_index=True)

# %%
### Quick function to pull column types and null counts - keep an eye on column types when modeling

def count_distinct_values(df, include_nulls=False):

    results = []
    
    for column in df.columns:
        distinct_count = df[column].nunique(dropna=not include_nulls)
        total_count = len(df)
        null_count = df[column].isnull().sum()
        
        results.append({
            'Column': column,
            'Data_Type': df[column].dtype,
            'Distinct_Count': distinct_count,
            'Total_Rows': total_count,
            'Null_Count': null_count,
            'Pct_Unique': round(distinct_count / total_count * 100, 2)
        })
    
    return pd.DataFrame(results).sort_values('Distinct_Count', ascending=False)

result = count_distinct_values(df_full)
result.head(len(result))
# Out:
#                                 Column Data_Type  Distinct_Count  Total_Rows  \
# 11                          request_id    object          559091      559091
# 0                        creation_date    object            3032      559091
# 5                             latitude   float64             380      559091
# 6                            longitude   float64             370      559091
# 9   number_of_potholes_filled_on_block   float64             269      559091
# 4                       community_area   float64              78      559091
# 1                                  zip   float64              64      559091
# 7                                  ssa   float64              53      559091
# 2                                 ward   float64              51      559091
# 3                      police_district   float64              27      559091
# 8                     current_activity    object              12      559091
# 10             completed_within_7_days   float64               2      559091
#
#     Null_Count  Pct_Unique
# 11           0      100.00
# 0            0        0.54
# 5          871        0.07
# 6          871        0.07
# 9       161175        0.05
# 4          331        0.01
# 1         2314        0.01
# 7       471719        0.01
# 2          331        0.01
# 3          332        0.00
# 8       166269        0.00
# 10      111819        0.00

# %%
#### At minimum, let's some basic ID columns as the correct type. 

df_full['zip'] = df_full['zip'].apply(lambda x: str(int(x)).zfill(5) if pd.notna(x) else None) 
df_full['ward'] = df_full['ward'].apply(lambda x: str(int(x)) if pd.notna(x) else None)
df_full['ssa'] = df_full['ssa'].apply(lambda x: str(int(x)) if pd.notna(x) else None)
df_full['police_district'] = df_full['police_district'].apply(lambda x: str(int(x)) if pd.notna(x) else None)
df_full['community_area'] = df_full['community_area'].apply(lambda x: str(int(x)) if pd.notna(x) else None)

    ### you can just run the above function again to check your work.

# %% [markdown]
# #### Join with other provided data

# %%
df_congestion = pd.read_csv('congestion_region.csv')
df_acs = pd.read_csv('community_acs.csv')

# %%
df_congestion.head()
# Out:
#    region_id                         region  min_speed  max_speed  avg_speed  \
# 0          1       Rogers Park - West Ridge          0      37.88  19.962090
# 1          2                 Far North West          0     109.43  26.106213
# 2          3   North Park-Albany-Linconl Sq          0      97.13  23.521621
# 3          4              Edge Water-Uptown          0      73.50  20.191830
# 4          5  Dunning-Portage-Belmont Cragn          0     142.50  22.779446
#
#    median_speed
# 0         22.50
# 1         27.27
# 2         23.18
# 3         20.45
# 4         24.55

# %%
df_acs.head()
# Out:
#    community_area  under_25_000  _25_000_to_49_999  _50_000_to_74_999  \
# 0     ALBANY PARK          1269               1916               1801
# 1  ARCHER HEIGHTS           223                752                441
# 2   ARMOUR SQUARE           701                798                370
# 3         ASHBURN           797               1351               1985
# 4  AUBURN GRESHAM          2541               2451               1592
#
#    _75_000_to_125_000  _125_000  male_0_to_17  male_18_to_24  male_25_to_34  \
# 0                2306      3379          4799           2955           4513
# 1                 795       739          1927            732           1102
# 2                 637       597          1300            487            871
# 3                3014      2735          5150           1964           2881
# 4                2202      1850          5803           1836           2964
#
#    male_35_to_49  ...  white  black_or_african_american  \
# 0           5442  ...  21496                       2228
# 1           1240  ...   6232                         10
# 2           1174  ...   2556                       1487
# 3           4178  ...  11297                      18124
# 4           3431  ...    760                      43414
#
#    american_indian_or_alaska  asian  native_hawaiin_or_pacific  other_race  \
# 0                        759   7124                          1        7888
# 1                        108    679                          0        3705
# 2                        107   8402                         61         212
# 3                        697    436                          0        7772
# 4                        119    399                          0         993
#
#    multiracial  white_not_hispanic_or_latino  hispanic_or_latino  \
# 0         8334                         16115               21108
# 1         3142                          2043               11097
# 2          325                          2226                 565
# 3         4517                          3774               19917
# 4          798                           491                1577
#
#              record_id
# 0     2023_ALBANY PARK
# 1  2023_ARCHER HEIGHTS
# 2   2023_ARMOUR SQUARE
# 3         2023_ASHBURN
# 4  2023_AUBURN GRESHAM
#
# [5 rows x 29 columns]

# %%
df_crosswalk = pd.read_csv('community_region_crosswalk.csv')
df_crosswalk.head()
# Out:
#    community_area_id community_area_name  region_id  \
# 0                  1         ROGERS PARK          1
# 1                  2          WEST RIDGE          1
# 2                  3              UPTOWN          4
# 3                  4      LINCOLN SQUARE          3
# 4                  5        NORTH CENTER          6
#
#                       region_name
# 0        Rogers Park - West Ridge
# 1        Rogers Park - West Ridge
# 2               Edge Water-Uptown
# 3    North Park-Albany-Linconl Sq
# 4  Irving Park-Avondale-North Ctr

# %%
result = count_distinct_values(df_crosswalk)
result.head(len(result))
# Out:
#                 Column Data_Type  Distinct_Count  Total_Rows  Null_Count  \
# 0    community_area_id     int64              77          77           0
# 1  community_area_name    object              77          77           0
# 2            region_id     int64              27          77           0
# 3          region_name    object              27          77           0
#
#    Pct_Unique
# 0      100.00
# 1      100.00
# 2       35.06
# 3       35.06

# %%
df_crosswalk['community_area_id'] = df_crosswalk['community_area_id'].apply(lambda x: str(int(x)) if pd.notna(x) else None)

# %%
### creating single unified dataset

## step 1 - join crosswalk to core data by community area name 

df_wide = pd.merge(df_full, df_crosswalk, left_on = 'community_area', right_on ='community_area_id', how = 'left')
df_wide.head()
# Out:
#   creation_date    zip ward police_district community_area  latitude  \
# 0    2012-03-02  60656   41              16             10    41.975
# 1    2016-03-31  60659   50              24              2    41.995
# 2    2018-02-27  60634   36              25             19    41.937
# 3    2011-04-06  60632   14               9             63    41.794
# 4    2018-03-28  60643   34              22             75    41.680
#
#    longitude   ssa current_activity  number_of_potholes_filled_on_block  \
# 0    -87.795  None    Dispatch Crew                                 5.0
# 1    -87.685  None    Final Outcome                                 4.0
# 2    -87.788  None    Final Outcome                                76.0
# 3    -87.688  None    Dispatch Crew                                 0.0
# 4    -87.669  None              NaN                                 NaN
#
#    completed_within_7_days                            request_id  \
# 0                      1.0  c6fb34de-4e79-4e83-ac3b-cbbf31d6d834
# 1                      1.0  a50411a7-2c2c-439c-8cd1-62cf18fc2d4a
# 2                      1.0  55eb1b82-ae52-4e1a-9476-169a59293cf0
# 3                      1.0  59a51854-7646-40d5-a30f-04306a6f9d2f
# 4                      1.0  06dbfc49-3118-4849-ad24-5d2fd3b1760b
#
#   community_area_id community_area_name  region_id  \
# 0                10        NORWOOD PARK        2.0
# 1                 2          WEST RIDGE        1.0
# 2                19      BELMONT CRAGIN        5.0
# 3                63           GAGE PARK       17.0
# 4                75         MORGAN PARK       25.0
#
#                         region_name
# 0                    Far North West
# 1          Rogers Park - West Ridge
# 2     Dunning-Portage-Belmont Cragn
# 3      Midway-Garfield Rdg-Clearing
# 4  Beverly-Mt Greenwood-Morgan Park

# %%
df_wide = pd.merge(df_wide,df_acs,left_on='community_area_name',right_on='community_area',how='left')
df_wide.head()
# Out:
#   creation_date    zip ward police_district community_area_x  latitude  \
# 0    2012-03-02  60656   41              16               10    41.975
# 1    2016-03-31  60659   50              24                2    41.995
# 2    2018-02-27  60634   36              25               19    41.937
# 3    2011-04-06  60632   14               9               63    41.794
# 4    2018-03-28  60643   34              22               75    41.680
#
#    longitude   ssa current_activity  number_of_potholes_filled_on_block  ...  \
# 0    -87.795  None    Dispatch Crew                                 5.0  ...
# 1    -87.685  None    Final Outcome                                 4.0  ...
# 2    -87.788  None    Final Outcome                                76.0  ...
# 3    -87.688  None    Dispatch Crew                                 0.0  ...
# 4    -87.669  None              NaN                                 NaN  ...
#
#      white black_or_african_american american_indian_or_alaska    asian  \
# 0  31029.0                     515.0                     144.0   2809.0
# 1  36943.0                    9310.0                     681.0  16696.0
# 2  27909.0                    3370.0                     993.0   1939.0
# 3  13619.0                    1403.0                     536.0    264.0
# 4   6807.0                   12770.0                      53.0    211.0
#
#    native_hawaiin_or_pacific other_race multiracial  \
# 0                        0.0     1759.0      3819.0
# 1                       17.0     6958.0      8615.0
# 2                       23.0    25743.0     14011.0
# 3                        1.0    13063.0      5764.0
# 4                        0.0      335.0      1112.0
#
#    white_not_hispanic_or_latino  hispanic_or_latino            record_id
# 0                       27986.0              7802.0    2023_NORWOOD PARK
# 1                       31486.0             17531.0      2023_WEST RIDGE
# 2                       10782.0             57511.0  2023_BELMONT CRAGIN
# 3                         995.0             31985.0       2023_GAGE PARK
# 4                        6485.0               981.0     2023_MORGAN PARK
#
# [5 rows x 45 columns]

# %%
df_wide = pd.merge(df_wide,df_congestion,on='region_id',how='left')
df_wide.head()
# Out:
#   creation_date    zip ward police_district community_area_x  latitude  \
# 0    2012-03-02  60656   41              16               10    41.975
# 1    2016-03-31  60659   50              24                2    41.995
# 2    2018-02-27  60634   36              25               19    41.937
# 3    2011-04-06  60632   14               9               63    41.794
# 4    2018-03-28  60643   34              22               75    41.680
#
#    longitude   ssa current_activity  number_of_potholes_filled_on_block  ...  \
# 0    -87.795  None    Dispatch Crew                                 5.0  ...
# 1    -87.685  None    Final Outcome                                 4.0  ...
# 2    -87.788  None    Final Outcome                                76.0  ...
# 3    -87.688  None    Dispatch Crew                                 0.0  ...
# 4    -87.669  None              NaN                                 NaN  ...
#
#    other_race multiracial white_not_hispanic_or_latino hispanic_or_latino  \
# 0      1759.0      3819.0                      27986.0             7802.0
# 1      6958.0      8615.0                      31486.0            17531.0
# 2     25743.0     14011.0                      10782.0            57511.0
# 3     13063.0      5764.0                        995.0            31985.0
# 4       335.0      1112.0                       6485.0              981.0
#
#              record_id                            region min_speed  max_speed  \
# 0    2023_NORWOOD PARK                    Far North West       0.0     109.43
# 1      2023_WEST RIDGE          Rogers Park - West Ridge       0.0      37.88
# 2  2023_BELMONT CRAGIN     Dunning-Portage-Belmont Cragn       0.0     142.50
# 3       2023_GAGE PARK      Midway-Garfield Rdg-Clearing       0.0     131.42
# 4     2023_MORGAN PARK  Beverly-Mt Greenwood-Morgan Park       0.0      71.93
#
#    avg_speed  median_speed
# 0  26.106213         27.27
# 1  19.962090         22.50
# 2  22.779446         24.55
# 3  24.723262         29.32
# 4  25.096574         29.32
#
# [5 rows x 50 columns]

# %%
### Splitting the data back into test + train after processing 

df_train_wide = df_wide[df_wide['completed_within_7_days'].notna()]
df_test_wide = df_wide[df_wide['completed_within_7_days'].isna()]

print(df_train_wide.shape)
print(df_test_wide.shape)
# Out:
# (447272, 50)
# (111819, 50)

# %% [markdown]
# ### Basic Model
#
# This model is just to show the basics of how to train a model in Python. This is not a very good model! Make it better through data cleaning, feature engineering, parameter tuning and pulling down additional features from the portal if you so choose!

# %%
## remind ourselves the columns we have, their data types, and null counts

result = count_distinct_values(df_train_wide)
result.head(len(result))
# Out:
#                                 Column Data_Type  Distinct_Count  Total_Rows  \
# 11                          request_id    object          447272      447272
# 0                        creation_date    object            3022      447272
# 5                             latitude   float64             380      447272
# 6                            longitude   float64             367      447272
# 9   number_of_potholes_filled_on_block   float64             258      447272
# 4                     community_area_x    object              78      447272
# 21                            _125_000   float64              77      447272
# 44                           record_id    object              77      447272
# 42        white_not_hispanic_or_latino   float64              77      447272
# 36           black_or_african_american   float64              77      447272
# 35                               white   float64              77      447272
# 34                    total_population   float64              77      447272
# 31                     female_35_to_49   float64              77      447272
# 27                             male_65   float64              77      447272
# 26                       male_50_to_64   float64              77      447272
# 24                       male_25_to_34   float64              77      447272
# 25                       male_35_to_49   float64              77      447272
# 13                 community_area_name    object              77      447272
# 16                    community_area_y    object              77      447272
# 12                   community_area_id    object              77      447272
# 17                        under_25_000   float64              76      447272
# 43                  hispanic_or_latino   float64              76      447272
# 41                         multiracial   float64              76      447272
# 40                          other_race   float64              76      447272
# 32                     female_50_to_64   float64              76      447272
# 30                     female_25_to_34   float64              76      447272
# 28                      female_0_to_17   float64              76      447272
# 33                           female_65   float64              76      447272
# 22                        male_0_to_17   float64              76      447272
# 20                  _75_000_to_125_000   float64              76      447272
# 18                   _25_000_to_49_999   float64              75      447272
# 29                     female_18_to_24   float64              75      447272
# 19                   _50_000_to_74_999   float64              74      447272
# 23                       male_18_to_24   float64              74      447272
# 38                               asian   float64              72      447272
# 37           american_indian_or_alaska   float64              66      447272
# 1                                  zip    object              64      447272
# 7                                  ssa    object              53      447272
# 2                                 ward    object              51      447272
# 39           native_hawaiin_or_pacific   float64              29      447272
# 48                           avg_speed   float64              27      447272
# 47                           max_speed   float64              27      447272
# 45                              region    object              27      447272
# 14                           region_id   float64              27      447272
# 3                      police_district    object              27      447272
# 15                         region_name    object              27      447272
# 49                        median_speed   float64              18      447272
# 8                     current_activity    object              11      447272
# 10             completed_within_7_days   float64               2      447272
# 46                           min_speed   float64               1      447272
#
#     Null_Count  Pct_Unique
# 11           0      100.00
# 0            0        0.68
# 5          680        0.08
# 6          680        0.08
# 9       128989        0.06
# 4          263        0.02
# 21        1524        0.02
# 44        1524        0.02
# 42        1524        0.02
# 36        1524        0.02
# 35        1524        0.02
# 34        1524        0.02
# 31        1524        0.02
# 27        1524        0.02
# 26        1524        0.02
# 24        1524        0.02
# 25        1524        0.02
# 13        1524        0.02
# 16        1524        0.02
# 12        1524        0.02
# 17        1524        0.02
# 43        1524        0.02
# 41        1524        0.02
# 40        1524        0.02
# 32        1524        0.02
# 30        1524        0.02
# 28        1524        0.02
# 33        1524        0.02
# 22        1524        0.02
# 20        1524        0.02
# 18        1524        0.02
# 29        1524        0.02
# 19        1524        0.02
# 23        1524        0.02
# 38        1524        0.02
# 37        1524        0.01
# 1         1844        0.01
# 7       377408        0.01
# 2          263        0.01
# 39        1524        0.01
# 48        1524        0.01
# 47        1524        0.01
# 45        1524        0.01
# 14        1524        0.01
# 3          264        0.01
# 15        1524        0.01
# 49        1524        0.00
# 8       133093        0.00
# 10           0        0.00
# 46        1524        0.00

# %%
print(df_train_wide.columns)
# Out:
# Index(['creation_date', 'zip', 'ward', 'police_district', 'community_area_x',
#        'latitude', 'longitude', 'ssa', 'current_activity',
#        'number_of_potholes_filled_on_block', 'completed_within_7_days',
#        'request_id', 'community_area_id', 'community_area_name', 'region_id',
#        'region_name', 'community_area_y', 'under_25_000', '_25_000_to_49_999',
#        '_50_000_to_74_999', '_75_000_to_125_000', '_125_000', 'male_0_to_17',
#        'male_18_to_24', 'male_25_to_34', 'male_35_to_49', 'male_50_to_64',
#        'male_65', 'female_0_to_17', 'female_18_to_24', 'female_25_to_34',
#        'female_35_to_49', 'female_50_to_64', 'female_65', 'total_population',
#        'white', 'black_or_african_american', 'american_indian_or_alaska',
#        'asian', 'native_hawaiin_or_pacific', 'other_race', 'multiracial',
#        'white_not_hispanic_or_latino', 'hispanic_or_latino', 'record_id',
#        'region', 'min_speed', 'max_speed', 'avg_speed', 'median_speed'],
#       dtype='object')

# %%
## Be careful what columns you include, this is a very basic drop just for demonstration purposes

drop_cols = ['creation_date', 'latitude', 'longitude', 'current_activity','number_of_potholes_filled_on_block',
             'completed_within_7_days','request_id', 'community_area_id', 'community_area_name', 'region_id',
             'region_name', 'community_area_y', 'record_id','region']

X = df_train_wide.drop(columns = drop_cols)
y = df_train_wide['completed_within_7_days']

# %%
## Checking my work

print(X.columns)
# Out:
# Index(['zip', 'ward', 'police_district', 'community_area_x', 'ssa',
#        'under_25_000', '_25_000_to_49_999', '_50_000_to_74_999',
#        '_75_000_to_125_000', '_125_000', 'male_0_to_17', 'male_18_to_24',
#        'male_25_to_34', 'male_35_to_49', 'male_50_to_64', 'male_65',
#        'female_0_to_17', 'female_18_to_24', 'female_25_to_34',
#        'female_35_to_49', 'female_50_to_64', 'female_65', 'total_population',
#        'white', 'black_or_african_american', 'american_indian_or_alaska',
#        'asian', 'native_hawaiin_or_pacific', 'other_race', 'multiracial',
#        'white_not_hispanic_or_latino', 'hispanic_or_latino', 'min_speed',
#        'max_speed', 'avg_speed', 'median_speed'],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=1234
)

# %%
# Create and train the model
# Random Forest takes almost any column type, this is your warning to check your column types and distros for other algorithms

rf_model = RandomForestClassifier(
    n_estimators=100,      # Number of trees in the forest
    max_depth=10,          # Maximum depth of each tree
    random_state=42
)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, random_state=42)

# %%
# Make predictions
y_pred_rf = rf_model.predict(X_test)

y_pred_proba_rf = rf_model.predict_proba(X_test)[:, 1]  # Probability of positive class
auc_rf = roc_auc_score(y_test, y_pred_proba_rf)
print(f"\nAUC: {auc_rf:.4f}")

# Evaluate the model
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print(f"\nAccuracy: {accuracy_rf:.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred_rf))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_rf))
# Out:
# AUC: 0.6255
#
# Accuracy: 0.5926
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.62      0.61     45935
#          1.0       0.58      0.57      0.58     43520
#
#     accuracy                           0.59     89455
#    macro avg       0.59      0.59      0.59     89455
# weighted avg       0.59      0.59      0.59     89455
#
# Confusion Matrix:
# [[28328 17607]
#  [18833 24687]]

# %%
print(df_test_wide.columns)
# Out:
# Index(['creation_date', 'zip', 'ward', 'police_district', 'community_area_x',
#        'latitude', 'longitude', 'ssa', 'current_activity',
#        'number_of_potholes_filled_on_block', 'completed_within_7_days',
#        'request_id', 'community_area_id', 'community_area_name', 'region_id',
#        'region_name', 'community_area_y', 'under_25_000', '_25_000_to_49_999',
#        '_50_000_to_74_999', '_75_000_to_125_000', '_125_000', 'male_0_to_17',
#        'male_18_to_24', 'male_25_to_34', 'male_35_to_49', 'male_50_to_64',
#        'male_65', 'female_0_to_17', 'female_18_to_24', 'female_25_to_34',
#        'female_35_to_49', 'female_50_to_64', 'female_65', 'total_population',
#        'white', 'black_or_african_american', 'american_indian_or_alaska',
#        'asian', 'native_hawaiin_or_pacific', 'other_race', 'multiracial',
#        'white_not_hispanic_or_latino', 'hispanic_or_latino', 'record_id',
#        'region', 'min_speed', 'max_speed', 'avg_speed', 'median_speed'],
#       dtype='object')

# %% [markdown]
# #### Scoring Test Rows

# %%
df_test_scoring = df_test_wide.drop(columns = drop_cols) ## these are the same columns we dropped from the training data!

# %%
test_predictions = rf_model.predict_proba(df_test_scoring)[:, 1] # This gives us the probabilities, not the class labels

test_predictions_df = pd.DataFrame({
    'request_id': df_test_wide['request_id'],
    'predicted_probabilitie': test_predictions
})

test_predictions_df.head()
# Out:
#                                   request_id  predicted_probabilitie
# 447272  b98b4a12-1e86-4634-b7e6-8a8d4c687ef6                0.404888
# 447273  90ad3297-203b-4636-81fa-26e279a323e6                0.552526
# 447274  c5e678b6-5fe5-4bc5-97ed-a9df3ba7f197                0.374305
# 447275  734f19b6-1a03-40f7-9aa0-2a575ff65fcc                0.462064
# 447276  f9cf7e4f-5745-4685-8378-03ee40040cc8                0.552526

# %%
test_predictions_df.to_csv('test_predictions.csv',index = True) ## send these to TA for AUC

# %% [markdown]
# Good luck! Reach out to Professor Cooman or Maura for help. Start early!!
